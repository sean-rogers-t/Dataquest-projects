# %%
import pandas as pd
import matplotlib.pyplot as plt
wnba = pd.read_csv('C:/Users/seanr/Downloads/wnba.csv')
parameter=wnba['Games Played'].max()
sample=wnba['Games Played'].sample(random_state=1)
statistic=sample.max()
sampling_error=parameter-statistic
wnba.head()
# Out:
#               Name Team  Pos  Height  Weight        BMI Birth_Place  \
# 0    Aerial Powers  DAL    F     183    71.0  21.200991          US
# 1      Alana Beard   LA  G/F     185    73.0  21.329438          US
# 2     Alex Bentley  CON    G     170    69.0  23.875433          US
# 3  Alex Montgomery  SAN  G/F     185    84.0  24.543462          US
# 4     Alexis Jones  MIN    G     175    78.0  25.469388          US
#
#            Birthdate  Age         College  ... OREB  DREB  REB  AST  STL  BLK  \
# 0   January 17, 1994   23  Michigan State  ...    6    22   28   12    3    6
# 1       May 14, 1982   35            Duke  ...   19    82  101   72   63   13
# 2   October 27, 1990   26      Penn State  ...    4    36   40   78   22    3
# 3  December 11, 1988   28    Georgia Tech  ...   35   134  169   65   20   10
# 4     August 5, 1994   23          Baylor  ...    3     9   12   12    7    0
#
#    TO  PTS  DD2  TD3
# 0  12   93    0    0
# 1  40  217    0    0
# ...

# %%
[parameter,statistic]
# Out:
# [32, 30]

# %%
sample_means=[]
parameter=wnba['PTS'].mean()
for i in range(100):
    samp=wnba['PTS'].sample(10,random_state=i)
    sample_mean_pts=samp.mean()
    sample_means.append(sample_mean_pts)
fig,ax=plt.subplots()
ax.scatter(range(1,101),sample_means)
ax.set_xlabel("Sample Number")
ax.set_ylabel("Sample Mean")
plt.axhline(parameter)
plt.show()

# %%
wnba.loc[wnba['Games Played']<12,:]
# Out:
#                     Name Team  Pos  Height  Weight        BMI Birth_Place  \
# 0          Aerial Powers  DAL    F     183    71.0  21.200991          US
# 9      Allison Hightower  WAS    G     178    77.0  24.302487          US
# 14          Aneika Henry  ATL  F/C     193    87.0  23.356332          JM
# 17       Bashaara Graves  CHI    F     188    91.0  25.746944          US
# 24         Brittany Boyd   NY    G     175    71.0  23.183673          US
# 35   Clarissa dos Santos  SAN    C     185    89.0  26.004383          BR
# 56         Glory Johnson  DAL    F     191    77.0  21.106878          US
# 64       Jennifer Hamson  IND    C     201    95.0  23.514269          US
# 65       Jessica Breland  CHI    F     191    77.0  21.106878          US
# 84      Lanay Montgomery  SEA    C     196    96.0  24.989588          US
# 90       Maimouna Diarra   LA    C     198    90.0  22.956841          SN
# 115       Sandrine Gruda   LA  F/C     193    84.0  22.550941          FR
#
# ...
